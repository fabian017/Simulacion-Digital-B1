# %% [markdown]
# # Generar una distribucion nomal a partir de numeros aleatorios
# ## Jose Fabian Jimenez Ovalle

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import norm 
import statistics 
# Graficando Poisson
mu =  100 # parametro de forma 
poisson = stats.poisson(mu) # Distribución
x = np.arange(poisson.ppf(0.01),
              poisson.ppf(0.99))
fmp = poisson.pmf(x) # Función de Masa de Probabilidad
plt.plot(x, fmp, '--')
plt.vlines(x, 0, fmp, colors='b', lw=5, alpha=0.5)
plt.title('Distribución Poisson')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
import random
for _ in range(10):
   print((random.gauss(0,1)))
# Out:
# -0.5842717531247839
# 0.40641476450005487
# 0.7309990148522146
# -0.5054762012251656
# -1.207200233902047
# -0.22045112351127327
# -0.41153981709184645
# -1.9951854187247164
# -0.8417416976087055
# -0.33091202952386845

# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline

campana=[random.gauss(1,0.5) for i in range(1000)]
plt.hist(campana, bins=15, color= "g")
plt.title('Distribución Poisson')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()
plt.show()

# %%
import matplotlib.pyplot as plot
import seaborn as sb

campana=[random.gauss(1,0.5) for i in range(1000)]

sb.displot(campana, color='#F2AB6D', kde=True) #creamos el gráfico en Seaborn

#configuramos en Matplotlib
plt.title('Distribución Poisson')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

plot.show()
