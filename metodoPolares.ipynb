# %%
import math as m
import random as rnd
import numpy as np
import time as t
from cgitb import text
import statistics as stat
import scipy.stats as stat2
import sys

N = 1000

Z1 = []
Z2 = []

inicio = t.time()
for i in range(N):
    U1 = rnd.random()
    U2 = rnd.random()
    R = m.sqrt(-2*m.log(U1))
    Th = 2 * m.pi * U2
    X = R * m.cos(Th)
    Y = R * m.sin(Th)
    Z1.append(X)
    Z2.append(Y)
final = t.time()



print(Z1)
print(Z2)
'''print(str(N) + " valores de la primera normal estandar")
print(Z1)
# impresión de la primera normal estandar y luego de la segunda
input("Presione enter para seguir")
print(str(N) + " valores de la segunda normal estandar")
print(Z2)

print("Generadas por el método polar")
input("Presione enter para seguir")'''

categ = round(1 + (m.log(len(Z1))/(m.log(2))))
print("{} categorias".format(categ))

maximo = max(Z1)
print("{} máximo".format(maximo))

obs, bins = np.histogram(Z1, categ)

print(f"obs: {obs}")
print(f"Rangos: {bins}")

probs = 1. * np.arange(len(bins)) / float(len(bins) - 1)
print("The CDF result is-",probs)
P = []

for k in range(1,categ+1):
    cc = probs[k] - probs[k-1]
    P.append(cc)

print(f"Probabilidad P entre intervalos: {P}")
print(f"Tamaño de P : {len(P)}")

PROBS = np.array(P)
esp = PROBS * len(Z1)

print(f"Esperados: {esp}")

print(f"Suma de esp: {sum(esp)}")
print(f"Suma de obs: {sum(obs)}")

est_chi = 0

for k in range(categ):
    est_chi = est_chi + ((obs[k] - esp[k])**2)/esp[k]

result = stat2.chisquare(obs, esp, categ - 1, axis = None )
print(f"chi: {result.statistic}")
print(f"chi manual: {est_chi}")
print(stat2.chi2.cdf(est_chi, categ - 1))
print(stat2.chi2.cdf(result.statistic, categ - 1))
# Out:
# [-0.4103936913214275, -0.8391628518990353, 0.0025222937296508164, -0.25637022031347906, -1.1202498730723325, -1.4050242018367223, 0.9170618488504848, 0.32932012321134024, -0.18930024972132947, -1.331637740743945, 0.5989636320662858, 1.3243797842802063, -0.01270885995113649, -0.06791952638059551, -0.5007794856039669, -0.2707659231300167, 0.5413940346487368, 1.4707286722477506, 1.4313131814299922, -0.5369575238215004, 1.5511854167886725, -0.8083510695287297, -1.2610749680247968, -0.16663909027661564, 0.5739766675717574, 0.3355391104549701, 0.47547328119412907, 0.28294688951634395, -0.29450160778392526, 0.3649510707835498, 1.0564986294947818, -0.4223419335630228, 0.6666220672003493, 0.14645395258256275, 0.8193428108466283, -1.933218876793042, -0.9082710671166941, 0.5283164120273046, 0.4640283715069181, 0.053017098770677236, -1.4981471616106563, -0.9813586141714169, -1.6429274114723726, 1.867325264266145, 1.2384144568678341, 1.5464710806631827, 0.18074215366177443, 0.37746798832738604, -1.3499662853376986, 1.8971325909526546, -0.091552711212559, -0.23873381401118574, -0.7503934342589106, -1.7539141298483445, 0.13189702625324484, 0.11693752307190904, 0.9108081113261398, 0.19114653285479077, 1.1123528325360748, 0.5076001723181103, 0.34717693755115436, -2.49823338547257, 0.4540298684133413, 1.9536058492814588, -1.52730778926178, -0.6870284756977315, 1.1338779837309783, 0.9157406582831381, 1.6601557207019493, 0.17446895610080435, -0.934766090956919, -0.6862411340173604, 1.8152563143540068, -1.225199486223724, -1.3872327466260772, 0.13513686717643691, 0.245075108072077, 0.2362455708862652, -2
#  0.54545455 0.63636364 0.72727273 0.81818182 0.90909091 1.        ]
# Probabilidad P entre intervalos: [0.09090909090909091, 0.09090909090909091, 0.09090909090909088, 0.09090909090909094, 0.09090909090909088, 0.09090909090909088, 0.09090909090909094, 0.09090909090909094, 0.09090909090909094, 0.09090909090909083, 0.09090909090909094]
# Tamaño de P : 11
# Esperados: [90.90909091 90.90909091 90.90909091 90.90909091 90.90909091 90.90909091
#  90.90909091 90.90909091 90.90909091 90.90909091 90.90909091]
# Suma de esp: 1000.0
# Suma de obs: 1000
# chi: 788.7760000000001
# chi manual: 788.7760000000002
# 1.0
# 1.0

# %%
Z3 = []
Z4 = []

count = 0
inicio = t.time()
for i in range(N):
    aceptado = False
    while aceptado == False:
        V1, V2 = 2*rnd.random() - 1, 2*rnd.random() - 1
        S = V1**2 + V2**2
        count += 1
        if ( S < 1):
            X = m.sqrt((-2*m.log(S))/S)*V1
            Y = m.sqrt((-2*m.log(S))/S)*V2
            Z3.append(X)
            Z4.append(Y)
            #print(str(X) + "," + str(Y))
            aceptado = True

final = t.time()


categ = round(1 + (m.log(len(Z3))/(m.log(2))))
print("{} categorias".format(categ))

maximo = max(Z3)
print("{} máximo".format(maximo))

obs, bins = np.histogram(Z3, categ)

print(f"obs: {obs}")
print(f"Rangos: {bins}")

probs = 1. * np.arange(len(bins)) / float(len(bins) - 1)
print("The CDF result is-",probs)
P = []

for k in range(1,categ+1):
    cc = probs[k] - probs[k-1]
    P.append(cc)

print(f"Probabilidad P entre intervalos: {P}")
print(f"Tamaño de P : {P}")

PROBS = np.array(P)
esp = PROBS * len(Z3)

print(f"Esperados: {esp}")

print(f"Suma de esp: {sum(esp)}")
print(f"Suma de obs: {sum(obs)}")

est_chi = 0

for k in range(categ):
    est_chi = est_chi + ((obs[k] - esp[k])**2)/esp[k]

result = stat2.chisquare(obs, esp, categ - 1, axis = None )
print(f"chi: {result.statistic}")
print(f"chi manual: {est_chi}")
print(stat2.chi2.cdf(est_chi, categ - 1))
print(stat2.chi2.cdf(result.statistic, categ - 1))
# Out:
# 11 categorias
# 3.2413735728146786 máximo
# obs: [  3   6  35  81 174 243 226 147  61  20   4]
# Rangos: [-3.62833042 -3.00381187 -2.37929333 -1.75477478 -1.13025624 -0.50573769
#   0.11878085  0.74329939  1.36781794  1.99233648  2.61685503  3.24137357]
# The CDF result is- [0.         0.09090909 0.18181818 0.27272727 0.36363636 0.45454545
#  0.54545455 0.63636364 0.72727273 0.81818182 0.90909091 1.        ]
# Probabilidad P entre intervalos: [0.09090909090909091, 0.09090909090909091, 0.09090909090909088, 0.09090909090909094, 0.09090909090909088, 0.09090909090909088, 0.09090909090909094, 0.09090909090909094, 0.09090909090909094, 0.09090909090909083, 0.09090909090909094]
# Tamaño de P : [0.09090909090909091, 0.09090909090909091, 0.09090909090909088, 0.09090909090909094, 0.09090909090909088, 0.09090909090909088, 0.09090909090909094, 0.09090909090909094, 0.09090909090909094, 0.09090909090909083, 0.09090909090909094]
# Esperados: [90.90909091 90.90909091 90.90909091 90.90909091 90.90909091 90.90909091
#  90.90909091 90.90909091 90.90909091 90.90909091 90.90909091]
# Suma de esp: 1000.0
# Suma de obs: 1000
# chi: 913.758
# chi manual: 913.758
# 1.0
# 1.0
